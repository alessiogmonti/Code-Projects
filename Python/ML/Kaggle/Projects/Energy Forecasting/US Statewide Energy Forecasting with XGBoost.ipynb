# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')

# %%
pjme = pd.read_csv('Data/PJME_hourly.csv', index_col=[0], parse_dates=[0])
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]
_ = pjme.plot(style='.', figsize=(15,5), color=color_pal[0], title='PJM East')

# %%
split_date = '01-Jan-2015'
pjme_train = pjme.loc[pjme.index <= split_date].copy()
pjme_test = pjme.loc[pjme.index > split_date].copy()

# %%
_ = pjme_test \
    .rename(columns={'PJME_MW': 'TEST SET'}) \
    .join(pjme_train.rename(columns={'PJME_MW': 'TRAINING SET'}), how='outer') \
    .plot(figsize=(15,5), title='PJM East', style='.')

# %%
display(pjme_test)
# Out:
#                      PJME_MW
# Datetime
# 2015-12-31 01:00:00  24305.0
# 2015-12-31 02:00:00  23156.0
# 2015-12-31 03:00:00  22514.0
# 2015-12-31 04:00:00  22330.0
# 2015-12-31 05:00:00  22773.0
# ...                      ...
# 2018-01-01 20:00:00  44284.0
# 2018-01-01 21:00:00  43751.0
# 2018-01-01 22:00:00  42402.0
# 2018-01-01 23:00:00  40164.0
# 2018-01-02 00:00:00  38608.0
#
# [31439 rows x 1 columns]

# %%
def create_features(df, label=None):
    """
    Creates time series features from datetime index
    """
    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.weekofyear
    
    X = df[['hour','dayofweek','quarter','month','year',
           'dayofyear','dayofmonth','weekofyear']]
    if label:
        y = df[label]
        return X, y
    return X

# %%
X_train, y_train = create_features(pjme_train, label='PJME_MW')
X_test, y_test = create_features(pjme_test, label='PJME_MW')
# Out:
# /opt/anaconda3/envs/TF/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   del sys.path[0]

# %%
display(X_train)
display(y_train)
# Out:
#                      hour  dayofweek  quarter  month  year  dayofyear  \
# Datetime
# 2002-12-31 01:00:00     1          1        4     12  2002        365
# 2002-12-31 02:00:00     2          1        4     12  2002        365
# 2002-12-31 03:00:00     3          1        4     12  2002        365
# 2002-12-31 04:00:00     4          1        4     12  2002        365
# 2002-12-31 05:00:00     5          1        4     12  2002        365
# ...                   ...        ...      ...    ...   ...        ...
# 2014-01-01 20:00:00    20          2        1      1  2014          1
# 2014-01-01 21:00:00    21          2        1      1  2014          1
# 2014-01-01 22:00:00    22          2        1      1  2014          1
# 2014-01-01 23:00:00    23          2        1      1  2014          1
# 2014-01-02 00:00:00     0          3        1      1  2014          2
#
#                      dayofmonth  weekofyear
# Datetime
# 2002-12-31 01:00:00          31           1
# 2002-12-31 02:00:00          31           1
# 2002-12-31 03:00:00          31           1
# 2002-12-31 04:00:00          31           1
# 2002-12-31 05:00:00          31           1
# ...                         ...         ...
# 2014-01-01 20:00:00           1           1
# 2014-01-01 21:00:00           1           1
# 2014-01-01 22:00:00           1           1
# 2014-01-01 23:00:00           1           1
# 2014-01-02 00:00:00           2           1
#
# [113927 rows x 8 columns]
# Datetime
# 2002-12-31 01:00:00    26498.0
# 2002-12-31 02:00:00    25147.0
# 2002-12-31 03:00:00    24574.0
# 2002-12-31 04:00:00    24393.0
# 2002-12-31 05:00:00    24860.0
#                         ...
# 2014-01-01 20:00:00    36193.0
# 2014-01-01 21:00:00    35601.0
# 2014-01-01 22:00:00    34242.0
# 2014-01-01 23:00:00    32215.0
# 2014-01-02 00:00:00    30159.0
# Name: PJME_MW, Length: 113927, dtype: float64

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=True) # Change verbose to True if you want to see it train
# Out:
# [16:28:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:29710.4	validation_1-rmse:28762.5
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:26822.6	validation_1-rmse:25892.2
# [2]	validation_0-rmse:24211.2	validation_1-rmse:23286.6
# [3]	validation_0-rmse:21885	validation_1-rmse:20967.5
# [4]	validation_0-rmse:19780.3	validation_1-rmse:18868.5
# [5]	validation_0-rmse:17910	validation_1-rmse:17017.7
# [6]	validation_0-rmse:16216.1	validation_1-rmse:15336.4
# [7]	validation_0-rmse:14717.8	validation_1-rmse:13861.5
# [8]	validation_0-rmse:13377.4	validation_1-rmse:12536.3
# [9]	validation_0-rmse:12184.1	validation_1-rmse:11362.1
# [10]	validation_0-rmse:11099.4	validation_1-rmse:10298.7
# [11]	validation_0-rmse:10135.2	validation_1-rmse:9357.58
# [12]	validation_0-rmse:9294.73	validation_1-rmse:8555.98
# [13]	validation_0-rmse:8552.87	validation_1-rmse:7853.17
# [14]	validation_0-rmse:7874.91	validation_1-rmse:7207.84
# [15]	validation_0-rmse:7276.11	validation_1-rmse:6651.82
# [16]	validation_0-rmse:6747	validation_1-rmse:6171.82
# [17]	validation_0-rmse:6299.44	validation_1-rmse:5774.19
# [18]	validation_0-rmse:5910.49	validation_1-rmse:5444.63
# [19]	validation_0-rmse:5540.57	validation_1-rmse:5131.21
# [20]	validation_0-rmse:5248.91	validation_1-rmse:4901.42
# [21]	validation_0-rmse:4967.62	validation_1-rmse:4681.66
# [22]	validation_0-rmse:4736.01	validation_1-rmse:4512.04
# [23]	validation_0-rmse:4527.3	validation_1-rmse:4360.53
# [24]	validation_0-rmse:4367.32	validation_1-rmse:4259.85
# [25]	validation_0-rmse:4207.46	validation_1-rmse:4150.42
# [26]	validation_0-rmse:4090.51	validation_1-rmse:4088.61
# [27]	validation_0-rmse:3973.03	validation_1-rmse:4044.89
# [28]	validation_0-rmse:3885	validation_1-rmse:3998.86
# [29]	validation_0-rmse:3795.7	validation_1-rmse:3947.27
# [30]	validation_0-rmse:3729.92	validation_1-rmse:3927.18
# [31]	validation_0-rmse:3676.43	validation_1-rmse:3911.59
# [32]	validation_0-rmse:3628.31	validation_1-rmse:3889.79
# [33]	validation_0-rmse:3582.71	validation_1-rmse:3873.4
# [34]	validation_0-rmse:3548.34	validation_1-rmse:3866.1
# [35]	validation_0-rmse:3516.28	validation_1-rmse:3859.39
# [36]	validation_0-rmse:3479.83	validation_1-rmse:3840.53
# [37]	validation_0-rmse:3446.23	validation_1-rmse:3844.63
# [38]	validation_0-rmse:3427.36	validation_1-rmse:3840.29
# [39]	validation_0-rmse:3408.65	validation_1-rmse:3835.73
# [40]	validation_0-rmse:3392.12	validation_1-rmse:3835.17
# [41]	validation_0-rmse:3368.23	validation_1-rmse:3834.3
# [42]	validation_0-rmse:3352.57	validation_1-rmse:3826.35
# [43]	validation_0-rmse:3338.75	validation_1-rmse:3820.16
# [44]	validation_0-rmse:3319.44	validation_1-rmse:3814.89
# [45]	validation_0-rmse:3308.8	validation_1-rmse:3812.75
# [46]	validation_0-rmse:3300.7	validation_1-rmse:3812.33
# [47]	validation_0-rmse:3294	validation_1-rmse:3813.9
# [48]	validation_0-rmse:3279.1	validation_1-rmse:3815.53
# [49]	validation_0-rmse:3267.82	validation_1-rmse:3813.69
# [50]	validation_0-rmse:3259.46	validation_1-rmse:3809.04
# [51]	validation_0-rmse:3253.54	validation_1-rmse:3808.22
# [52]	validation_0-rmse:3247.34	validation_1-rmse:3805.86
# [53]	validation_0-rmse:3233.91	validation_1-rmse:3811.56
# [54]	validation_0-rmse:3225.73	validation_1-rmse:3809.98
# [55]	validation_0-rmse:3220.05	validation_1-rmse:3806.03
# [56]	validation_0-rmse:3206.15	validation_1-rmse:3793.43
# [57]	validation_0-rmse:3200.42	validation_1-rmse:3789.56
# [58]	validation_0-rmse:3192.51	validation_1-rmse:3788.28
# [59]	validation_0-rmse:3188.53	validation_1-rmse:3787.1
# [60]	validation_0-rmse:3183.72	validation_1-rmse:3785.06
# [61]	validation_0-rmse:3171.4	validation_1-rmse:3778.57
# [62]	validation_0-rmse:3168.23	validation_1-rmse:3779.03
# [63]	validation_0-rmse:3162.51	validation_1-rmse:3777.94
# [64]	validation_0-rmse:3157.56	validation_1-rmse:3775.59
# [65]	validation_0-rmse:3152.96	validation_1-rmse:3773.72
# [66]	validation_0-rmse:3149.28	validation_1-rmse:3772.82
# [67]	validation_0-rmse:3145.51	validation_1-rmse:3770.81
# [68]	validation_0-rmse:3135.92	validation_1-rmse:3766.06
# [69]	validation_0-rmse:3133.61	validation_1-rmse:3765.8
# [70]	validation_0-rmse:3128.76	validation_1-rmse:3762.49
# [71]	validation_0-rmse:3125.09	validation_1-rmse:3761.22
# [72]	validation_0-rmse:3122.63	validation_1-rmse:3760.97
# [73]	validation_0-rmse:3119.23	validation_1-rmse:3760.12
# [74]	validation_0-rmse:3116.22	validation_1-rmse:3760.84
# [75]	validation_0-rmse:3113.49	validation_1-rmse:3761.16
# [76]	validation_0-rmse:3106.53	validation_1-rmse:3754.07
# [77]	validation_0-rmse:3103.54	validation_1-rmse:3753.85
# [78]	validation_0-rmse:3100.83	validation_1-rmse:3753.24
# [79]	validation_0-rmse:3098.31	validation_1-rmse:3752.05
# [80]	validation_0-rmse:3097.02	validation_1-rmse:3751.89
# [81]	validation_0-rmse:3094.46	validation_1-rmse:3750.1
# [82]	validation_0-rmse:3092.18	validation_1-rmse:3747.54
# [83]	validation_0-rmse:3090.06	validation_1-rmse:3746.7
# [84]	validation_0-rmse:3086.29	validation_1-rmse:3746.26
# [85]	validation_0-rmse:3080.8	validation_1-rmse:3744.7
# [86]	validation_0-rmse:3074.08	validation_1-rmse:3748.64
# [87]	validation_0-rmse:3072	validation_1-rmse:3747.87
# [88]	validation_0-rmse:3070.11	validation_1-rmse:3745.81
# [89]	validation_0-rmse:3068.15	validation_1-rmse:3742.59
# [90]	validation_0-rmse:3062.98	validation_1-rmse:3748.18
# [91]	validation_0-rmse:3058.4	validation_1-rmse:3749.18
# [92]	validation_0-rmse:3056.73	validation_1-rmse:3749.68
# [93]	validation_0-rmse:3054.68	validation_1-rmse:3748.79
# [94]	validation_0-rmse:3048.13	validation_1-rmse:3749.03
# [95]	validation_0-rmse:3043.93	validation_1-rmse:3743.66
# [96]	validation_0-rmse:3040.38	validation_1-rmse:3744.23
# [97]	validation_0-rmse:3038.8	validation_1-rmse:3742.92
# [98]	validation_0-rmse:3037.66	validation_1-rmse:3744.01
# [99]	validation_0-rmse:3035.46	validation_1-rmse:3743.77
# [100]	validation_0-rmse:3034.02	validation_1-rmse:3743.08
# [101]	validation_0-rmse:3029.44	validation_1-rmse:3740.03
# [102]	validation_0-rmse:3025.56	validation_1-rmse:3740.39
# [103]	validation_0-rmse:3024.05	validation_1-rmse:3737.7
# [104]	validation_0-rmse:3020.48	validation_1-rmse:3736.36
# [105]	validation_0-rmse:3018.99	validation_1-rmse:3737.19
# [106]	validation_0-rmse:3017.39	validation_1-rmse:3736.54
# [107]	validation_0-rmse:3016.61	validation_1-rmse:3737.52
# [108]	validation_0-rmse:3010.54	validation_1-rmse:3740.19
# [109]	validation_0-rmse:3009.2	validation_1-rmse:3737.55
# [110]	validation_0-rmse:3005.2	validation_1-rmse:3736.5
# [111]	validation_0-rmse:3003.69	validation_1-rmse:3736.47
# [112]	validation_0-rmse:3002.93	validation_1-rmse:3737.39
# [113]	validation_0-rmse:3000.89	validation_1-rmse:3736.44
# [114]	validation_0-rmse:2997.99	validation_1-rmse:3736.85
# [115]	validation_0-rmse:2996.17	validation_1-rmse:3736.33
# [116]	validation_0-rmse:2991.05	validation_1-rmse:3734.19
# [117]	validation_0-rmse:2985.62	validation_1-rmse:3732.26
# [118]	validation_0-rmse:2981.82	validation_1-rmse:3733.41
# [119]	validation_0-rmse:2980.73	validation_1-rmse:3731.41
# [120]	validation_0-rmse:2979.58	validation_1-rmse:3730.7
# [121]	validation_0-rmse:2978.42	validation_1-rmse:3730.05
# [122]	validation_0-rmse:2974.68	validation_1-rmse:3728.98
# [123]	validation_0-rmse:2971.48	validation_1-rmse:3730.2
# [124]	validation_0-rmse:2969.6	validation_1-rmse:3730.22
# [125]	validation_0-rmse:2968.1	validation_1-rmse:3730.04
# [126]	validation_0-rmse:2963.23	validation_1-rmse:3726.8
# [127]	validation_0-rmse:2960.75	validation_1-rmse:3723.37
# [128]	validation_0-rmse:2959.47	validation_1-rmse:3724.38
# [129]	validation_0-rmse:2958.71	validation_1-rmse:3725.32
# [130]	validation_0-rmse:2957.85	validation_1-rmse:3723.69
# [131]	validation_0-rmse:2956.9	validation_1-rmse:3723.66
# [132]	validation_0-rmse:2954.04	validation_1-rmse:3724.84
# [133]	validation_0-rmse:2952.94	validation_1-rmse:3725.81
# [134]	validation_0-rmse:2952.36	validation_1-rmse:3727.14
# [135]	validation_0-rmse:2950.32	validation_1-rmse:3727.16
# [136]	validation_0-rmse:2949.53	validation_1-rmse:3727.08
# [137]	validation_0-rmse:2946.55	validation_1-rmse:3726.22
# [138]	validation_0-rmse:2943.86	validation_1-rmse:3725.11
# [139]	validation_0-rmse:2939.9	validation_1-rmse:3720.9
# [140]	validation_0-rmse:2939.16	validation_1-rmse:3719.24
# [141]	validation_0-rmse:2935.64	validation_1-rmse:3715.27
# [142]	validation_0-rmse:2934.18	validation_1-rmse:3715.1
# [143]	validation_0-rmse:2933.73	validation_1-rmse:3715.9
# [144]	validation_0-rmse:2933.1	validation_1-rmse:3715.75
# [145]	validation_0-rmse:2932.23	validation_1-rmse:3716.29
# [146]	validation_0-rmse:2931.2	validation_1-rmse:3717.22
# [147]	validation_0-rmse:2930.35	validation_1-rmse:3718.02
# [148]	validation_0-rmse:2928.75	validation_1-rmse:3717.76
# [149]	validation_0-rmse:2923.14	validation_1-rmse:3712.2
# [150]	validation_0-rmse:2920.09	validation_1-rmse:3714.78
# [151]	validation_0-rmse:2919.09	validation_1-rmse:3714.25
# [152]	validation_0-rmse:2918.28	validation_1-rmse:3713.52
# [153]	validation_0-rmse:2917.79	validation_1-rmse:3713.66
# [154]	validation_0-rmse:2917.19	validation_1-rmse:3714.73
# [155]	validation_0-rmse:2916.37	validation_1-rmse:3714.26
# [156]	validation_0-rmse:2915.65	validation_1-rmse:3716.12
# [157]	validation_0-rmse:2915.18	validation_1-rmse:3716.75
# [158]	validation_0-rmse:2910.8	validation_1-rmse:3718.45
# [159]	validation_0-rmse:2908.21	validation_1-rmse:3716.42
# [160]	validation_0-rmse:2905.92	validation_1-rmse:3716.91
# [161]	validation_0-rmse:2902.12	validation_1-rmse:3730.8
# [162]	validation_0-rmse:2899.8	validation_1-rmse:3736.36
# [163]	validation_0-rmse:2896.59	validation_1-rmse:3737.21
# [164]	validation_0-rmse:2893.5	validation_1-rmse:3752.03
# [165]	validation_0-rmse:2891.46	validation_1-rmse:3759.02
# [166]	validation_0-rmse:2890.96	validation_1-rmse:3759.38
# [167]	validation_0-rmse:2890.29	validation_1-rmse:3758.99
# [168]	validation_0-rmse:2889.22	validation_1-rmse:3759.5
# [169]	validation_0-rmse:2888.72	validation_1-rmse:3760.48
# [170]	validation_0-rmse:2888.08	validation_1-rmse:3763.08
# [171]	validation_0-rmse:2885.45	validation_1-rmse:3761.42
# [172]	validation_0-rmse:2885.06	validation_1-rmse:3762.12
# [173]	validation_0-rmse:2884.05	validation_1-rmse:3764.25
# [174]	validation_0-rmse:2881.64	validation_1-rmse:3767.64
# [175]	validation_0-rmse:2877.44	validation_1-rmse:3762.06
# [176]	validation_0-rmse:2876.03	validation_1-rmse:3762.38
# [177]	validation_0-rmse:2873.71	validation_1-rmse:3759.87
# [178]	validation_0-rmse:2873.28	validation_1-rmse:3759.68
# [179]	validation_0-rmse:2870.85	validation_1-rmse:3757.93
# [180]	validation_0-rmse:2868.8	validation_1-rmse:3759.2
# [181]	validation_0-rmse:2867.49	validation_1-rmse:3755.82
# [182]	validation_0-rmse:2865.01	validation_1-rmse:3757.61
# [183]	validation_0-rmse:2863.78	validation_1-rmse:3755.76
# [184]	validation_0-rmse:2862.51	validation_1-rmse:3759.81
# [185]	validation_0-rmse:2859.9	validation_1-rmse:3758.46
# [186]	validation_0-rmse:2859.17	validation_1-rmse:3758.33
# [187]	validation_0-rmse:2857.63	validation_1-rmse:3759.08
# [188]	validation_0-rmse:2857.05	validation_1-rmse:3758.94
# [189]	validation_0-rmse:2856.31	validation_1-rmse:3758.57
# [190]	validation_0-rmse:2852.87	validation_1-rmse:3754.35
# [191]	validation_0-rmse:2851.87	validation_1-rmse:3753.87
# [192]	validation_0-rmse:2848.81	validation_1-rmse:3755.22
# [193]	validation_0-rmse:2847.77	validation_1-rmse:3755.12
# [194]	validation_0-rmse:2847.09	validation_1-rmse:3754.4
# [195]	validation_0-rmse:2844.31	validation_1-rmse:3754.43
# [196]	validation_0-rmse:2842.91	validation_1-rmse:3754.73
# [197]	validation_0-rmse:2840.54	validation_1-rmse:3754.88
# [198]	validation_0-rmse:2838.7	validation_1-rmse:3754.7
# [199]	validation_0-rmse:2837.79	validation_1-rmse:3753.65
# Stopping. Best iteration:
# [149]	validation_0-rmse:2923.14	validation_1-rmse:3712.2
# XGBRegressor(n_estimators=1000)

# %%
_ = plot_importance(reg, height=0.9)

# %%
pjme_test['MW_Prediction'] = reg.predict(X_test)
pjme_all = pd.concat([pjme_test, pjme_train], sort=False)

# %%
_ = pjme_all[['PJME_MW','MW_Prediction']].plot(figsize=(15, 5))

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_xbound(lower='01-01-2015', upper='02-01-2015')
ax.set_ylim(0, 60000)
plot = plt.suptitle('January 2015 Forecast vs Actuals')

# %%
# Plot the forecast with the actuals
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_xbound(lower='01-01-2015', upper='01-08-2015')
ax.set_ylim(0, 60000)
plot = plt.suptitle('First Week of January Forecast vs Actuals')

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='07-01-2015', upper='07-08-2015')
plot = plt.suptitle('First Week of July Forecast vs Actuals')

# %%
mean_squared_error(y_true=pjme_test['PJME_MW'],
                   y_pred=pjme_test['MW_Prediction'])
# Out:
# 13780445.55710396

# %%
mean_absolute_error(y_true=pjme_test['PJME_MW'],
                   y_pred=pjme_test['MW_Prediction'])
# Out:
# 2848.891429322955

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(y_true=pjme_test['PJME_MW'],
                   y_pred=pjme_test['MW_Prediction'])
# Out:
# 8.94944673745318

# %%
pjme_test['error'] = pjme_test['PJME_MW'] - pjme_test['MW_Prediction']
pjme_test['abs_error'] = pjme_test['error'].apply(np.abs)
error_by_day = pjme_test.groupby(['year','month','dayofmonth']) \
    .mean()[['PJME_MW','MW_Prediction','error','abs_error']]

# %%
error_by_day.sort_values('error', ascending=True).head(10)
# Out:
#                             PJME_MW  MW_Prediction        error    abs_error
# year month dayofmonth
# 2016 7     4           28399.958333   36986.964844 -8587.006429  8587.006429
# 2017 2     24          26445.083333   33814.503906 -7369.422445  7369.422445
# 2015 12    25          24466.083333   31584.923828 -7118.841390  7118.841390
# 2017 2     20          27070.583333   34100.781250 -7030.197754  7030.197754
# 2015 7     3           30024.875000   37021.031250 -6996.156169  6996.156169
# 2017 6     28          30531.208333   37526.589844 -6995.380371  6995.380371
#      2     8           28523.833333   35511.699219 -6987.864258  6987.864258
#      9     2           24201.458333   31180.390625 -6978.933105  6978.933105
#      2     25          24344.458333   31284.279297 -6939.820150  6939.820150
# 2018 2     21          27572.500000   34477.417969 -6904.919352  6904.919352

# %%
error_by_day.sort_values('abs_error', ascending=False).head(10)
# Out:
#                             PJME_MW  MW_Prediction         error     abs_error
# year month dayofmonth
# 2016 8     13          45185.833333   31753.224609  13432.608887  13432.608887
#            14          44427.333333   31058.818359  13368.514404  13368.514404
#      9     10          40996.166667   29786.179688  11209.987793  11209.987793
#            9           43836.958333   32831.035156  11005.923828  11005.923828
# 2015 2     20          44694.041667   33814.503906  10879.535889  10879.535889
# 2018 1     6           43565.750000   33435.265625  10130.485921  10130.485921
# 2016 8     12          45724.708333   35609.312500  10115.394287  10115.394287
# 2017 5     19          38032.583333   28108.976562   9923.606689   9923.606689
#      12    31          39016.000000   29314.683594   9701.315430   9701.315430
# 2015 2     21          40918.666667   31284.279297   9634.388184   9634.388184

# %%
error_by_day.sort_values('abs_error', ascending=True).head(10)
# Out:
#                             PJME_MW  MW_Prediction       error   abs_error
# year month dayofmonth
# 2016 10    3           27705.583333   27775.351562  -69.768148  229.585205
# 2015 10    28          28500.958333   28160.875000  340.083740  388.023356
# 2016 10    8           25183.333333   25535.669922 -352.337402  401.017090
#      5     1           24503.625000   24795.419922 -291.794515  428.289307
# 2017 10    29          24605.666667   24776.271484 -170.605225  474.628988
# 2016 9     16          29258.500000   29397.271484 -138.770833  491.070312
#      3     20          27989.416667   27620.132812  369.284831  499.750488
#      10    2           24659.083333   25134.919922 -475.836670  516.188232
# 2017 10    14          24949.583333   25399.728516 -450.145996  520.855794
# 2015 5     6           28948.666667   28710.271484  238.396077  546.640544

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='08-13-2016', upper='08-14-2016')
plot = plt.suptitle('Aug 13, 2016 - Worst Predicted Day')

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='10-03-2016', upper='10-04-2016')
plot = plt.suptitle('Oct 3, 2016 - Best Predicted Day')

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='08-13-2016', upper='08-14-2016')
plot = plt.suptitle('Aug 13, 2016 - Worst Predicted Day')
