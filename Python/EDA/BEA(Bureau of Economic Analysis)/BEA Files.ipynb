# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Section1All.xlsx', sheet_name='T10101-Q')

display(df)
# Out:
#    Table 1.1.1. Percent Change From Preceding Period in Real Gross Domestic Product  \
# 0       [Percent] Seasonally adjusted at annual rates
# 1                Quarterly data from 1947Q2 to 2021Q1
# 2                         Bureau of Economic Analysis
# 3                        Data published June 24, 2021
# 4                    File created Jun 23 2021  4:39PM
# 5                                                 NaN
# 6                                                Line
# 7                                                   1
# 8                                                   2
# 9                                                   3
# 10                                                  4
# 11                                                  5
# 12                                                  6
# 13                                                  7
# 14                                                  8
# 15                                                  9
# ...
